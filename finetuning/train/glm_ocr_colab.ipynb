# %% [markdown]
# # GLM-OCR Unsloth training on Google Colab
#
# **Runtime → Change runtime type → GPU** (T4 or better) before running.
#
# Set `REPO_URL` below to your fork if needed. Upload `finetuning/output/` (train.txt, test.txt, labels.json + images) or mount Drive and link it.

# %%
REPO_URL = "https://github.com/Meloneneis/glm_ocr.git"

# !git clone --depth 1 $REPO_URL glm_ocr
# %cd glm_ocr

# %%
# !pip install -q "transformers>=5.2.0" accelerate tqdm pypdfium2 kernels unsloth trl google-genai

# %%
import torch
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")

# %%
# Run training. Ensure finetuning/output/ has train.txt, test.txt, labels.json and images.
# Options: --load-in-4bit, --train-size 2000 --test-size 200, --epochs 3
# !python finetuning/train/train_unsloth.py
